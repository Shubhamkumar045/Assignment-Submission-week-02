# %%
Q1. How do you comment code in Python? What are the different types of comments?
Comments can be used to explain Python code. Comments can be used to make the code more readable.
1-Single-line comments: Use the # symbol to comment a single line.
2-Multi-line comments: Use triple quotes ''' or """ for comments that span multiple lines, often used for documentation.

Q2. What are variables in Python? How do you declare and assign values to variables?
Answer-A variable is a string of characters and numbers associated with a piece of information.
The assignment operator, denoted by the “=” symbol, is the operator that is used to assign values to variables in Python.
The line x=1 takes the known value, 1, and assigns that value to the variable with name “x”.

Q3. How do you convert one data type to another in Python?
Answer--Python defines type conversion functions like int(), float(), str() to directly convert one data type into another.
In Python, we can convert one data type to another using type casting or conversion functions.Some common methods to perform type conversion
A--Using Conversion Functions
B--Implicit Type Conversion (Type Coercion)
C--Using String Formatting
D--Using List and Tuple Conversion
E--Using eval()

Q4. How do you write and execute a Python script from the command line?
Answer-- A--Write Your Python Script
         B--Navigate to the Command Line
         C--Execute the Python Script
         D--View the Output
         python first_script.py
         Hello World! 
Q5. Given a list my_list = [1, 2, 3, 4, 5], write the code to slice the list and obtain the sub-list [2, 3].
Answer--my_list = [1, 2, 3, 4, 5]
sub_list = my_list[1:3]
print(sub_list)  # Output: [2, 3]

Q6. What is a complex number in mathematics, and how is it represented in Python?
Answer--The complex data type in python consists of two values,
the first one is the real part of the complex number, and the second one is the imaginary part of the complex number.
We usually denote the real part using i and the imaginary part with j. For example, (3 + 7j) or (3i + 7j).

Q7. What is the correct way to declare a variable named age and assign the value 25 to it?
Answer--  age = 25

Q8. Declare a variable named price and assign the value 9.99 to it. What data type does this variable
belong to?
Answer--price = 9.99
The variable price is assigned the value 9.99, which is a decimal number.
In Python, such numbers are represented using the float data type.

Q9. Create a variable named name and assign your full name to it as a string. How would you print the
value of this variable?
Answer--    name = "Your Full Name"
            print(name)
Replace "Your Full Name" with your actual full name.

To print the value of the name variable, you can use the print() function

Q10. Given the string "Hello, World!", extract the substring "World".
Answer--string = "Hello, World!"
substring = string[7:]
print(substring)  # Output: "World!"


Q11. Create a variable named "is_student" and assign it a boolean value indicating whether you are
currently a student or not.
Answer--To create a variable named is_student and assign it a boolean value indicating whether you are currently a student or not
